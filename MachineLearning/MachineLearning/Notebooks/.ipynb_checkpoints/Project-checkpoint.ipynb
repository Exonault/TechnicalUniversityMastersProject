# %% [markdown]
# # Проект по Методи и софтуер за машинно обучение
# Студент: Кристиян Кръчмаров <br>
# Фак. номер: 791324005 <br>

# %% [markdown]
# ## Зареждане на данните

# %%
import pandas as pd

path = "../Data/"
data = pd.read_csv(path + "shuffle_email_spam_classification.csv")
data.info()
print("\nNaN in data: {}".format(data.isna().any().any()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5172 entries, 0 to 5171
# Columns: 3002 entries, Email No. to Prediction
# dtypes: int64(3001), object(1)
# memory usage: 118.5+ MB
#
# NaN in data: False

# %%
data = data.iloc[:, 1:]  # remove 'Email No' column

X = data.iloc[:, :-1]  # explanatory variables
Y = data.iloc[:, -1]  # result

print(X.shape)
print(Y.shape)
# Out:
# (5172, 3000)
# (5172,)

# %% [markdown]
# ## Helper methods
# `get_metrics` е за трениране на класификатори и изчисляване на метрики. Метриките които се изчисляват са следните
# * False positive ratio (FPR)
# * True positive ration (TPR)
# * Area under the curve (AUC)
# * Confusion Matrix
# * Accuracy
# * Classification Report

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report

def get_metrics(classifier, x_train, y_train, x_test, y_test):
    """Train a classifier and get different metrics"""

    classifier.fit(x_train, y_train)  # train

    predicted = classifier.predict(x_test)  # get prediction
    probabilities = classifier.predict_proba(x_test)  # get probabilities of each class
    probabilities = probabilities[:, 1]

    fpr, tpr, threshold = roc_curve(y_test, probabilities)  # ROC curve
    auc = roc_auc_score(y_test, probabilities)  # AUC score

    conf_matrix = confusion_matrix(y_test, predicted)  # confusion matrix

    accuracy = classification_report(y_test, predicted, output_dict=True)['accuracy']  # accuracy
    cl_report = classification_report(y_test, predicted, output_dict=False)  # classification report

    return {
        "ACC": accuracy,
        "AUC": auc,
        "TPR": tpr,
        "FPR": fpr,
        "Threshold": threshold,
        "ConfusionMatrix": conf_matrix,
        "ClassificationReport": cl_report,
    }

# %% [markdown]
# `get_metrics_train_and_test` се използва за намирането на различните метрики спрямо двата различни сценария:
#    1. Данните за обучение и тест са еднакви
#    2. Данните за обучение и тест са различни <br>
# Също така се чертаят ROC кривите при задаване на флага `plot_roc_curve=True`. <br>
# Връща се dictionary с двата различни сета от метрики: <br>
# * `train-train` - данните за обучение и тест са едни и същи, в случая са обучителните данни `x_train`, `y_train`
# * `train-test` - данните за обучение и тест са различни

# %%
import matplotlib.pyplot as plt

def get_metrics_train_and_test(classifier, x_train, y_train, x_test, y_test, plot_roc_curve=False):
    """
    Get metrics for a classifier when training and test data are the same and also train and test data are different.
    Plot the ROC curve.
    Return the metrics for each training scenario
    """
    train_train = get_metrics(classifier, x_train, y_train, x_train, y_train)
    train_test = get_metrics(classifier, x_train, y_train, x_test, y_test)

    # Plot setup
    if plot_roc_curve:
        fg, axes = plt.subplots(1, 2, figsize=(15, 5))

        axes[0].set_xlim([-0.05, 1.05])
        axes[0].set_ylim([-0.05, 1.05])
        axes[0].plot([0, 1], [0, 1], linestyle="-", color='k')
        axes[0].set_title("ROC (Test set)")
        axes[0].set_xlabel("False Positive Rate")
        axes[0].set_ylabel("True Positive Rate")

        axes[1].set_xlim([-0.05, 1.05])
        axes[1].set_ylim([-0.05, 1.05])
        axes[1].plot([0, 1], [0, 1], linestyle="-", color='k')
        axes[1].set_title("ROC (Training set)")
        axes[1].set_xlabel("False Positive Rate")
        axes[1].set_ylabel("True Positive Rate")

        axes[0].plot(train_test["FPR"], train_test["TPR"], marker="", color="green", alpha=0.6)
        axes[1].plot(train_train["FPR"], train_train["TPR"], marker="", color="red", alpha=0.6)

        plt.show()

    return {
        "train-train": train_train,
        "train-test": train_test,
    }

# %% [markdown]
# Метода `k_fold_cross_validation` изпълнява кръстосано валидиране за определен класификатор.
# Използва се `KFold` за разделянето на данни. <br>
# Чертаят ROC кривите при задаване на флага `plot_roc_curve=True`. <br>
# За всяко разделение се тренира класификатора и се изчисляват следните метрики
# * номер на разделението
# * точност при обучителни и тестови данни
# * точност при обучителни данни
# * процентно отношение на двете точностти
# * AUC за обучителни и тестови данни
# * AUC за обучителни данни
# * процентно отношение на двете AUC-та
# * Confusion matrix за обучителни и тестови данни

# %%
from sklearn.model_selection import KFold

def k_fold_cross_validation_classifier(classifier, X: pd.DataFrame, Y: pd.DataFrame, splits=10, plot_roc_curve=False):
    """
    Perform k-fold cross validation for classifier.
    Plot the ROC curve for each fold.
    Return performance metrics for each fold.
    """

    kf = KFold(n_splits=splits, shuffle=True)

    df_columns = ["Fold", "ACC Test", "ACC Training", "ACC ratio", "AUC Test", "AUC Training", "AUC ratio", "CONF_MTX"]
    performance_df = pd.DataFrame(columns=df_columns)

    # plot setup
    if plot_roc_curve:
        fg, axes = plt.subplots(1, 2, figsize=(15, 5))

        axes[0].set_xlim([-0.05, 1.05])
        axes[0].set_ylim([-0.05, 1.05])
        axes[0].plot([0, 1], [0, 1], linestyle="-", color='k')
        axes[0].title.set_text("k-Fold ROC (Test set)")
        axes[0].set_xlabel("False Positive Rate")
        axes[0].set_ylabel("True Positive Rate")

        axes[1].set_xlim([-0.05, 1.05])
        axes[1].set_ylim([-0.05, 1.05])
        axes[1].plot([0, 1], [0, 1], linestyle="-", color='k')
        axes[1].title.set_text("k-Fold ROC (Training set)")
        axes[1].set_xlabel("False Positive Rate")
        axes[1].set_ylabel("True Positive Rate")

    i = 0
    #k-fold
    for trainIndex, testIndex in kf.split(X, Y):
        print(f"Processing fold {i + 1}...")
        X_train, X_test = X.iloc[trainIndex], X.iloc[testIndex]
        Y_train, Y_test = Y.iloc[trainIndex], Y.iloc[testIndex]

        metrics_train_train = get_metrics(classifier, X_train, Y_train, X_train, Y_train)
        metrics_train_test = get_metrics(classifier, X_train, Y_train, X_test, Y_test)

        if plot_roc_curve:
            axes[0].plot(metrics_train_test["FPR"], metrics_train_test["TPR"], marker="", color="blue", alpha=0.6)
            axes[1].plot(metrics_train_train["FPR"], metrics_train_train["TPR"], marker="", color="orange", alpha=0.6)

        temp = {'Fold': i,
                'ACC Test': metrics_train_test["ACC"],
                'ACC Training': metrics_train_train["ACC"],
                'ACC ratio': metrics_train_test["ACC"] / metrics_train_train["ACC"],
                'AUC Test': metrics_train_test["AUC"],
                'AUC Training': metrics_train_train["AUC"],
                'AUC ratio': metrics_train_test["AUC"] / metrics_train_train["AUC"],
                'CONF_MTX': metrics_train_test["ConfusionMatrix"]}

        temp_df = pd.DataFrame([temp])
        performance_df = pd.concat([performance_df, temp_df], ignore_index=True)
        i = i + 1

    if plot_roc_curve:
        plt.show()

    return performance_df

# %% [markdown]
# Метода `print_metrics` се използва за принтирането на различни метрики получени от `get_metrics_train_and_test`

# %%
def print_metrics(metrics_train_and_test):
    """Print metrics for differently trained classifier"""
    train_train = metrics_train_and_test.get('train-train', 'not-found')
    train_test = metrics_train_and_test.get('train-test', 'not-found')

    print("Train-Train ACC: {}".format(train_train.get('ACC', 'not-found')))
    print("Train-Test ACC: {}".format(train_test.get('ACC', 'not-found')))
    print("\n")
    print("Train-Train AUC: {}".format(train_train.get('AUC', 'not-found')))
    print("Train-Test AUC: {}".format(train_test.get('AUC', 'not-found')))
    print("\n")
    print("Train-Train Confusion Matrix: \n {}".format(train_train.get('ConfusionMatrix', 'not-found')))
    print("\n")
    print("Train-Test Confusion Matrix: \n {}".format(train_test.get('ConfusionMatrix', 'not-found')))
    # print("\n")
    # print("Train-Train Classification report: \n {}".format(train_train.get('ClassificationReport', 'not-found')))
    # print("\n")
    # print("Train-Test Classification report: \n {}".format(train_test.get('ClassificationReport', 'not-found')))

# %% [markdown]
# Метода `plot_history_nn` показва графиките на точността и загубата за една невронна мрежа

# %%
def plot_history_nn(nn):
    """Plots graphs for accuracy and loss for the duration of the training of the Neural Network"""
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))

    ax[0].plot(nn.history['accuracy'], color='blue')
    ax[0].plot(nn.history['val_accuracy'], color='green')
    ax[0].set_title('Model Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend(['Train', 'Validate'])
    ax[0].axis(ymin=0.5, ymax=1.1)
    ax[0].margins(0.03)

    ax[1].plot(nn.history['loss'], color='blue')
    ax[1].plot(nn.history['val_loss'], color='red')
    ax[1].set_title('Model loss')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Loss')
    ax[1].legend(['Train', 'Validate'])
    ax[1].margins(0.03)

    plt.show()

# %% [markdown]
# ## 1. Logistic regression
# Първо ще обуча един класификатор `LogisticRegression` без preprocessing <br>
# Използвам `random_state`, за да може данните които се използват за обучаване и тест да са едни и същи и само промяната на модела да влияе на резултатите.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (4137, 3000) (4137,)
# (1035, 3000) (1035,)

# %%
from sklearn.linear_model import LogisticRegression

logistic_regression = LogisticRegression()

lr_metrics_train_and_test = get_metrics_train_and_test(logistic_regression, X_train, Y_train, X_test, Y_test,
                                                       plot_roc_curve=True)
# Out:
# D:\Python venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# D:\Python venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Проверяваме модела чрез k_fold cross валидация

# %%
import warnings  # to not log the same warning on every iteration

warnings.filterwarnings('ignore')
lr_k_fold = k_fold_cross_validation_classifier(logistic_regression, X, Y, plot_roc_curve=True)
warnings.filterwarnings('default')
# Out:
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
# Processing fold 4...
# Processing fold 5...
# Processing fold 6...
# Processing fold 7...
# Processing fold 8...
# Processing fold 9...
# Processing fold 10...

# %%
print_metrics(lr_metrics_train_and_test)
# Out:
# Train-Train ACC: 0.9869470630891951
# Train-Test ACC: 0.9710144927536232
#
#
# Train-Train AUC: 0.9993217856604816
# Train-Test AUC: 0.9876248034231796
#
#
# Train-Train Confusion Matrix:
#  [[2898   35]
#  [  19 1185]]
#
#
# Train-Test Confusion Matrix:
#  [[719  20]
#  [ 10 286]]

# %% [markdown]
# Има следното предупреждение: `ConvergenceWarning: lbfgs failed to converge (status=1): STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.` <br>
# За тази цел ще използвам някакъв вид preprocessing за да се провери дали може да се избегне този бъдещ проблем. <br>
# В случая съм използвал `MinMaxScaler` чрез който всичките ни данни ще са в диапазона $[0,1]$.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (4137, 3000) (4137,)
# (1035, 3000) (1035,)

# %%
logistic_regression = LogisticRegression()
lr_metrics_train_and_test = get_metrics_train_and_test(logistic_regression, X_train, Y_train, X_test, Y_test,
                                                       plot_roc_curve=True)

# %%
lr_k_fold = k_fold_cross_validation_classifier(logistic_regression, X_scaled, Y, plot_roc_curve=True)
# Out:
# Processing fold 1...
# C:\Users\krist\AppData\Local\Temp\ipykernel_15380\3724743709.py:57: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   performance_df = pd.concat([performance_df, temp_df], ignore_index=True)
# Processing fold 2...
# Processing fold 3...
# Processing fold 4...
# Processing fold 5...
# Processing fold 6...
# Processing fold 7...
# Processing fold 8...
# Processing fold 9...
# Processing fold 10...

# %%
print_metrics(lr_metrics_train_and_test)
# Out:
# Train-Train ACC: 0.9886391104665216
# Train-Test ACC: 0.9835748792270531
#
#
# Train-Train AUC: 0.9992679816001441
# Train-Test AUC: 0.9973119262699778
#
#
# Train-Train Confusion Matrix:
#  [[2922   11]
#  [  36 1168]]
#
#
# Train-Test Confusion Matrix:
#  [[729  10]
#  [  7 289]]

# %% [markdown]
# Точността $ACC$ се повиши до Train-Test $ACC \approx 0.98$, което е подобрение. <br>
# Не се наблюдава underfitting или overfitting

# %% [markdown]
# ## 2. Random forest
# Ще обучим един `RandomForestClassifier` без preprocessing на данните за да видим как ще се справи

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (4137, 3000) (4137,)
# (1035, 3000) (1035,)

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier()

rf_metrics_train_and_test = get_metrics_train_and_test(random_forest, X_train, Y_train, X_test, Y_test,
                                                       plot_roc_curve=True)

# %%
rf_k_fold = k_fold_cross_validation_classifier(random_forest, X, Y, plot_roc_curve=True)
# Out:
# Processing fold 1...
# C:\Users\krist\AppData\Local\Temp\ipykernel_15380\3724743709.py:57: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   performance_df = pd.concat([performance_df, temp_df], ignore_index=True)
# Processing fold 2...
# Processing fold 3...
# Processing fold 4...
# Processing fold 5...
# Processing fold 6...
# Processing fold 7...
# Processing fold 8...
# Processing fold 9...
# Processing fold 10...

# %%
print_metrics(rf_metrics_train_and_test)
# Out:
# Train-Train ACC: 1.0
# Train-Test ACC: 0.9758454106280193
#
#
# Train-Train AUC: 1.0
# Train-Test AUC: 0.9973804995794171
#
#
# Train-Train Confusion Matrix:
#  [[2933    0]
#  [   0 1204]]
#
#
# Train-Test Confusion Matrix:
#  [[727  12]
#  [ 13 283]]

# %% [markdown]
# Модела се справя добре с данните на които е обучен, както и тестовите данни. <br>
# Да видим дали с някакъв вид preprocessing ще има промяна. За целта ще използвам отново `MinMaxScaller`.

# %%
min_max_scaler = MinMaxScaler()
X_scaled = min_max_scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (4137, 3000) (4137,)
# (1035, 3000) (1035,)

# %%
random_forest = RandomForestClassifier()
random_forest.fit(X_train, Y_train)
rf_metrics_train_and_test = get_metrics_train_and_test(random_forest, X_train, Y_train, X_test, Y_test, plot_roc_curve=True)

# %%
rf_k_fold = k_fold_cross_validation_classifier(random_forest, X_scaled, Y, plot_roc_curve=True)
# Out:
# Processing fold 1...
# C:\Users\krist\AppData\Local\Temp\ipykernel_15380\3724743709.py:57: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   performance_df = pd.concat([performance_df, temp_df], ignore_index=True)
# Processing fold 2...
# Processing fold 3...
# Processing fold 4...
# Processing fold 5...
# Processing fold 6...
# Processing fold 7...
# Processing fold 8...
# Processing fold 9...
# Processing fold 10...

# %%
print_metrics(rf_metrics_train_and_test)
# Out:
# Train-Train ACC: 1.0
# Train-Test ACC: 0.9758454106280193
#
#
# Train-Train AUC: 1.0
# Train-Test AUC: 0.9969599166148557
#
#
# Train-Train Confusion Matrix:
#  [[2933    0]
#  [   0 1204]]
#
#
# Train-Test Confusion Matrix:
#  [[725  14]
#  [ 11 285]]

# %% [markdown]
# Има пренебрежително подобрение за точността. <br>
# Следователно preprocessing не е необходим. <br>
# Няма наличиние на underfiting или overfitting.

# %% [markdown]
# ## 3. Neural network
# Ще се наложи използването на `MinMaxScaller`, тъй като невронните мрежи са чуствителни към мащаба на данните

# %%
min_max_scaler = MinMaxScaler()
X_scaled = min_max_scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (4137, 3000) (4137,)
# (1035, 3000) (1035,)

# %% [markdown]
# За първата мрежа ще използваме следната структура за слоевете:
# 1. 32 неврона с активационна функция relu
# 2. 16 неврона с активационна функция relu
# 3. 1 резултатен с активационна функция sigmoid
#
# Модела който ще използвам е `Sequential`. <br>
# С `layers.Input` се задават броя на началните параметри. <br>
# За `optimizer` ще използваме `adam`, a за `loss` - `binary_crossentropy`

# %%
from keras import models, layers

NUMBER_INPUTS = X_train.shape[1]
print(NUMBER_INPUTS)

network_layers = [
    layers.Input(shape=(NUMBER_INPUTS,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
]

neural_network = models.Sequential(network_layers)

neural_network.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

neural_network.summary()
# Out:
# 3000
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │        96,032 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 96,577 (377.25 KB)
#  Trainable params: 96,577 (377.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = neural_network.fit(X_train, Y_train, epochs=50, batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7267 - loss: 0.5722 - val_accuracy: 0.8937 - val_loss: 0.2804
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9273 - loss: 0.2159 - val_accuracy: 0.9662 - val_loss: 0.1382
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9822 - loss: 0.1036 - val_accuracy: 0.9758 - val_loss: 0.0888
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.0618 - val_accuracy: 0.9831 - val_loss: 0.0693
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0385 - val_accuracy: 0.9903 - val_loss: 0.0604
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9961 - loss: 0.0301 - val_accuracy: 0.9903 - val_loss: 0.0618
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0225 - val_accuracy: 0.9855 - val_loss: 0.0535
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0207 - val_accuracy: 0.9855 - val_loss: 0.0576
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0159 - val_accuracy: 0.9879 - val_loss: 0.0537
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0142 - val_accuracy: 0.9855 - val_loss: 0.0566
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0116 - val_accuracy: 0.9831 - val_loss: 0.0580
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0102 - val_accuracy: 0.9831 - val_loss: 0.0588
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0079 - val_accuracy: 0.9807 - val_loss: 0.0615
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0076 - val_accuracy: 0.9807 - val_loss: 0.0651
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0065 - val_accuracy: 0.9783 - val_loss: 0.0682
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0060 - val_accuracy: 0.9783 - val_loss: 0.0737
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0053 - val_accuracy: 0.9783 - val_loss: 0.0754
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0050 - val_accuracy: 0.9783 - val_loss: 0.0799
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0041 - val_accuracy: 0.9758 - val_loss: 0.0837
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0041 - val_accuracy: 0.9758 - val_loss: 0.0897
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0040 - val_accuracy: 0.9758 - val_loss: 0.0919
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 0.9758 - val_loss: 0.0977
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0046 - val_accuracy: 0.9734 - val_loss: 0.1032
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9710 - val_loss: 0.1082
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 0.9710 - val_loss: 0.1100
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0027 - val_accuracy: 0.9734 - val_loss: 0.1137
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0021 - val_accuracy: 0.9710 - val_loss: 0.1176
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9710 - val_loss: 0.1224
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0026 - val_accuracy: 0.9710 - val_loss: 0.1239
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9710 - val_loss: 0.1285
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 0.9710 - val_loss: 0.1317
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9710 - val_loss: 0.1357
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9710 - val_loss: 0.1407
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9710 - val_loss: 0.1403
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9710 - val_loss: 0.1425
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9710 - val_loss: 0.1448
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9710 - val_loss: 0.1516
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 0.9710 - val_loss: 0.1537
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.8275e-04 - val_accuracy: 0.9710 - val_loss: 0.1563
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.3087e-04 - val_accuracy: 0.9710 - val_loss: 0.1599
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9686 - val_loss: 0.2092
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0060 - val_accuracy: 0.9662 - val_loss: 0.2223
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9686 - val_loss: 0.1682
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9686 - val_loss: 0.1599
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9686 - val_loss: 0.1621
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9686 - val_loss: 0.1641
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9686 - val_loss: 0.1654
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 7.7454e-04 - val_accuracy: 0.9686 - val_loss: 0.1663
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 6.9820e-04 - val_accuracy: 0.9686 - val_loss: 0.1675
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 0.9686 - val_loss: 0.1696

# %%
plot_history_nn(history)

# %% [markdown]
# Невронната мрежа започва да overfit-ва oколо 5тата епоха, защото loss функцията за валидационнитте данни започва да расте. <br>
# Точността на валидационните данни спира да се увеличава и започва леко да намалява. <br>
# Като опит за подобрение на резултата ще добавя още eдин слой и ще намаля броя епохи

# %%
from keras import regularizers

network_layers2 = [
    layers.Input(shape=(NUMBER_INPUTS,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
]

neural_network2 = models.Sequential(network_layers2)
neural_network2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

neural_network2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │       192,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 194,689 (760.50 KB)
#  Trainable params: 194,689 (760.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history2 = neural_network2.fit(X_train, Y_train, epochs=30, batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7288 - loss: 0.5903 - val_accuracy: 0.8816 - val_loss: 0.2512
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9405 - loss: 0.1746 - val_accuracy: 0.9758 - val_loss: 0.0942
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0614 - val_accuracy: 0.9831 - val_loss: 0.0611
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0301 - val_accuracy: 0.9879 - val_loss: 0.0554
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0163 - val_accuracy: 0.9662 - val_loss: 0.1554
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0225 - val_accuracy: 0.9807 - val_loss: 0.1014
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0228 - val_accuracy: 0.9807 - val_loss: 0.0658
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0101 - val_accuracy: 0.9831 - val_loss: 0.0613
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0084 - val_accuracy: 0.9807 - val_loss: 0.0682
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0067 - val_accuracy: 0.9807 - val_loss: 0.0653
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0050 - val_accuracy: 0.9831 - val_loss: 0.0655
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0049 - val_accuracy: 0.9831 - val_loss: 0.0681
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9807 - val_loss: 0.0705
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0040 - val_accuracy: 0.9783 - val_loss: 0.0759
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 0.9807 - val_loss: 0.0760
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.9783 - val_loss: 0.0769
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0039 - val_accuracy: 0.9807 - val_loss: 0.0818
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 0.9783 - val_loss: 0.0823
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0024 - val_accuracy: 0.9807 - val_loss: 0.0866
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.9807 - val_loss: 0.0912
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9807 - val_loss: 0.0908
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.9807 - val_loss: 0.0971
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 0.9807 - val_loss: 0.0971
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9783 - val_loss: 0.1065
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0025 - val_accuracy: 0.9783 - val_loss: 0.1040
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9831 - val_loss: 0.1030
# Epoch 27/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 9.6624e-04 - val_accuracy: 0.9831 - val_loss: 0.1058
# Epoch 28/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9758 - val_loss: 0.1145
# Epoch 29/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 8.8894e-04 - val_accuracy: 0.9807 - val_loss: 0.1110
# Epoch 30/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0010 - val_accuracy: 0.9807 - val_loss: 0.1127

# %%
plot_history_nn(history2)

# %% [markdown]
# Отново има наличие на overfitting, защото loss функцията за валидационните данни расте и е по голяма от тази за обучителните данни. <br>
# Точността на валидационните данни започва да намалява много леко <br>
# Този път като идея за решаване на проблема ще добавя регуляризация под формата на `kernel_regularizer` като в случая ще бъде L2. <br>
# Също така ще добавя няколко `Dropout` слоя, които ще изключват част от невроните по време на обучение.

# %%
network_layers3 = [
    layers.Input(shape=(NUMBER_INPUTS,)),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
]

neural_network3 = models.Sequential(network_layers3)

neural_network3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

neural_network3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 64)             │       192,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 194,689 (760.50 KB)
#  Trainable params: 194,689 (760.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history3 = neural_network3.fit(X_train, Y_train, epochs=30, batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6621 - loss: 1.8460 - val_accuracy: 0.7343 - val_loss: 0.8787
# Epoch 2/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8061 - loss: 0.7922 - val_accuracy: 0.9372 - val_loss: 0.6094
# Epoch 3/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9152 - loss: 0.5794 - val_accuracy: 0.9541 - val_loss: 0.4591
# Epoch 4/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9418 - loss: 0.4617 - val_accuracy: 0.9734 - val_loss: 0.3967
# Epoch 5/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9614 - loss: 0.3998 - val_accuracy: 0.9831 - val_loss: 0.3669
# Epoch 6/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9633 - loss: 0.3760 - val_accuracy: 0.9662 - val_loss: 0.3533
# Epoch 7/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9605 - loss: 0.3562 - val_accuracy: 0.9517 - val_loss: 0.3437
# Epoch 8/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9610 - loss: 0.3324 - val_accuracy: 0.9807 - val_loss: 0.3088
# Epoch 9/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9628 - loss: 0.3260 - val_accuracy: 0.9783 - val_loss: 0.3127
# Epoch 10/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9623 - loss: 0.3268 - val_accuracy: 0.9783 - val_loss: 0.2941
# Epoch 11/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.3066 - val_accuracy: 0.9807 - val_loss: 0.2970
# Epoch 12/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9618 - loss: 0.3085 - val_accuracy: 0.9855 - val_loss: 0.2864
# Epoch 13/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.3038 - val_accuracy: 0.9469 - val_loss: 0.3122
# Epoch 14/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.3134 - val_accuracy: 0.9734 - val_loss: 0.2970
# Epoch 15/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9713 - loss: 0.2963 - val_accuracy: 0.9807 - val_loss: 0.2876
# Epoch 16/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.2953 - val_accuracy: 0.9831 - val_loss: 0.2795
# Epoch 17/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.2849 - val_accuracy: 0.9686 - val_loss: 0.2829
# Epoch 18/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9672 - loss: 0.2995 - val_accuracy: 0.9783 - val_loss: 0.2862
# Epoch 19/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9694 - loss: 0.2921 - val_accuracy: 0.9855 - val_loss: 0.2678
# Epoch 20/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9734 - loss: 0.2653 - val_accuracy: 0.9783 - val_loss: 0.2790
# Epoch 21/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9678 - loss: 0.2810 - val_accuracy: 0.9807 - val_loss: 0.2756
# Epoch 22/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.2735 - val_accuracy: 0.9855 - val_loss: 0.2545
# Epoch 23/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9764 - loss: 0.2544 - val_accuracy: 0.9396 - val_loss: 0.2958
# Epoch 24/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9619 - loss: 0.2878 - val_accuracy: 0.9783 - val_loss: 0.2767
# Epoch 25/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.2702 - val_accuracy: 0.9710 - val_loss: 0.2951
# Epoch 26/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9713 - loss: 0.2875 - val_accuracy: 0.9734 - val_loss: 0.2837
# Epoch 27/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.2729 - val_accuracy: 0.9879 - val_loss: 0.2520
# Epoch 28/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9733 - loss: 0.2686 - val_accuracy: 0.9758 - val_loss: 0.2698
# Epoch 29/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9720 - loss: 0.2723 - val_accuracy: 0.9831 - val_loss: 0.2671
# Epoch 30/30
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.3303 - val_accuracy: 0.9734 - val_loss: 0.2930

# %%
plot_history_nn(history3)

# %% [markdown]
# Тук моделът изглежда да е балансиран. <br>
# Графиките на точността са близки една до друга и е с високи стойности. За загубата имаме близки графики и стойностите намаляват.

# %%
neural_network3.save("nn_3.keras")

# %%
import tensorflow as tf
model = tf.keras.models.load_model("nn_3.keras")

# %%
predictions = model.predict(X_test)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
predicted_class = [int(round(p[0])) for p in predictions]
result = {"real": Y_test, "predicted": predicted_class}
results = pd.DataFrame(result)

total = len(results)
matches = (results["real"] == results["predicted"]).sum()
mismatches = total - matches

# Compute percentages
match_percentage = (matches / total) * 100
mismatch_percentage = (mismatches / total) * 100

# Print results
print(f"Matching Percentage: {match_percentage:.2f}%")
print(f"Non-Matching Percentage: {mismatch_percentage:.2f}%")
# Out:
# Matching Percentage: 96.52%
# Non-Matching Percentage: 3.48%
