# %%
import pandas as pd

# %%
data_df = pd.read_csv("files/data_ex2.csv")
data_df
# Out:
#         NO     NO2  AirTemp  Press   UMR      WD    WS     O3    PM10
# 0    -1.39   13.92     -1.4  941.0  73.7  281.29  2.00  44.79   34.65
# 1    -1.35   11.51     -1.4  941.0  72.9  282.62  1.69  44.79   34.65
# 2    -1.24   11.46     -1.5  942.0  72.3  275.63  1.86  44.79   34.65
# 3    -0.96    9.69     -1.6  942.0  73.0  278.97  2.08  44.79   34.65
# 4    -0.77   10.80     -1.6  943.0  72.1  274.92  1.87  44.79   34.65
# ..     ...     ...      ...    ...   ...     ...   ...    ...     ...
# 64  655.61  233.33      0.1  949.0  80.0  206.05  0.52   9.63  290.84
# 65  553.24  183.67     -0.8  950.0  84.4  240.89  0.72   9.63  290.84
# 66  354.38  150.86     -0.9  949.0  85.6  214.22  1.15   9.63  290.84
# 67  297.02  136.31     -1.1  950.0  84.2  188.69  0.68   9.63  290.84
# 68  277.17  110.27     -1.9  949.0  86.8  225.86  0.78   9.63  290.84
#
# [69 rows x 9 columns]

# %%
X = data_df[["AirTemp", "Press", "UMR"]]
Y = data_df[["NO", "NO2", "O3", "PM10"]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

X_scaled = RobustScaler().fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)
