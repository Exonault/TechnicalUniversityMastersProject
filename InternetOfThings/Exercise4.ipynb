# %%
import pandas as pd

# %%
data_df = pd.read_csv("files/Data_4.csv")
data_df
# Out:
#        Unnamed: 0     NO    NO2  AirTemp  Press   UMR     O3   PM10
# 0               0  -1.39  13.92     -1.4  941.0  73.7  44.79  34.65
# 1               1  -1.35  11.51     -1.4  941.0  72.9  44.79  34.65
# 2               2  -1.24  11.46     -1.5  942.0  72.3  44.79  34.65
# 3               3  -0.96   9.69     -1.6  942.0  73.0  44.79  34.65
# 4               4  -0.77  10.80     -1.6  943.0  72.1  44.79  34.65
# ...           ...    ...    ...      ...    ...   ...    ...    ...
# 55692       60619  15.93  57.44     -4.4  950.0  76.2  25.17  40.44
# 55693       60620  31.56  58.31     -5.2  950.0  79.7  25.17  40.44
# 55694       60621  43.72  59.66     -5.8  950.0  80.4  25.17  40.44
# 55695       60622  29.62  56.70     -6.5  950.0  80.1  25.17  40.44
# 55696       60623  24.33  55.29     -6.6  950.0  79.3  25.17  40.44
#
# [55697 rows x 8 columns]

# %%
X = data_df[["AirTemp", "Press", "UMR"]]
Y = data_df[["NO", "NO2", "O3", "PM10"]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

X_scaled = RobustScaler().fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
from sklearn.neural_network import MLPRegressor

reg = MLPRegressor(max_iter=1000)
reg.fit(X_train, Y_train)
# Out:
# MLPRegressor(max_iter=1000)

# %%
print(reg.score(X_test,Y_test))
# Out:
# 0.260043327315866

# %%
import numpy as np
a = np.array([[25, 955, 80]])

# %%
a_scalled = RobustScaler().fit_transform(a)
reg.predict(a_scalled)
# Out:
# array([[18.77251669, 36.41558476, 48.26934464, 35.88544335]])

# %%
import joblib
joblib.dump(reg, 'regressor.joblib')
# Out:
# ['regressor.joblib']
